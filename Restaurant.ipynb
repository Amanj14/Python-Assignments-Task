# %% [markdown]
#  > **Code Restaurant**

# %%
# Starter Menu
starter = {1:'Papad',2:'Tamato soup',3:'Gobi Tikka',4:'Mashroom Tikka',5:'Rolls'}
starter1 = {'Rolls':'Veg Cheese Rolls','Papad':'Onion Grilled','Mashroom Tikka':'Tandoori Grilled Mashrooms','Gobi Tikka':'Tandoori Fried Gobi with Paneer','Tamato soup':'Tamato soup with bread',}
starter_rs = {'Rolls':75,'Papad':35,'Tamato soup':90,'Gobi Tikka':100,'Mashroom Tikka':200}

# Main Course Menu
main_course ={1:'Veg Biryani',2:'Shahi Paneer',3:'Daal Tadka',4:'Dudh Sev'}
main_course1 = {'Veg Biryani':'Paneer with Biryani','Shahi Paneer':'Spicy Grilled Paneer','Daal Tadka':'Simple Indian Daal Tadka','Dudh Sev':'Sev Bhaji'}
main_course_rs = {'Veg Biryani':250,'Shahi Paneer':150,'Daal Tadka':110,'Dudh Sev':150}

# Desert Menu
desert = {1:'Chocolate Ice Cream',2:'Butter-scotch Ice Cream',3:'Gulab Jamun'}
desert1 = {'Chocolate Ice Cream':'Havmor Chocolate Cone','Butter-scotch Ice Cream':'Amul Cup Ice-cream','Gulab Jamun':'Pure Ghee Indian Gulab Jamun (2pec)'}
desert_rs = {'Chocolate Ice Cream':45,'Butter-scotch Ice Cream':80,'Gulab Jamun':70}

print('*'*5,'Welcome to Code Restaurant','*'*5,'\n\n')

# Table capacity and occupency
table2 ={1:(1,2),2:(2,3),3:(3,4),4:(4,5),5:(6,7),6:(7,8),7:(7,8),8:(7,8)}
table3= {(1,2):False,(3,4):False,(5,6):False,(7,8):False}
x=int(input("For how many people: "))
if x not in table2:
    print('Sorry no table for',x,'persons')
else :
    print('Table number for',x,'person :',table2[x])

# Waiter Handling Table
waiter = {1:'Waiter 1',2:'Waiter 1',3:'Waiter 2',4:'Waiter 2',5:'Waiter 3',6:'Waiter 3',7:'Waiter 4',8:'Waiter 4'}
y= int(input("Select a Table as per table number: "))
if y in waiter:
    print('\nKindly take your seats',waiter[y],"will take your order \n\n Hello Sir\Mam I'm",waiter[y]," Here is our Menu Card\n")
else :
    print('Kindly input correct name')

print('*'*28,'| MENU |','*'*28,'\n')
print('_____( Starter )_____\n\n',starter)
print('\n_____( Main Course )_____\n\n',main_course)
print('\n_____( Desert )_____\n\n',desert,'\n')
print('*'*60)

    
# order
r = ('y')
def order1():
    a=0
    while r in ('y'):
        order = input('What you like to order: ')
        if order in starter1:
            a1=starter_rs.get(order)
            a=a+a1
            print('Rs:',starter_rs.get(order))
        elif order in main_course1:
            a1=main_course_rs.get(order)
            a=a+a1
            print('Rs:',main_course_rs.get(order))
        elif order in desert1:
            a1=desert_rs.get(order)
            a=a+a1
            print('Rs:',desert_rs.get(order))
        elif order== 'N' or order== 'n':
            print('\n','$'*3,'Thank you for odering , Your bill is','$'*3,'\n ')
            break
        else:
            print('Please input a valid dish')
    print('Rs=',a,'+ 18% GST')
    b=(a/100)*18
    print('Total Rs =',a+b,'/-')
    
    #Waiter serving
    print("\nWaiter name: ",waiter[y])
    
    
    # Date and time
    curr_datetime = datetime.datetime.now()
    print("\nCurrent time:")
    print(curr_datetime)
order1()

print("\n\nTo Improve our services we need your Feedback , Kindly share your exprience with Code Restaurant\n")
input()
print("\nThank you for visiting _/\_")
# Out:
# ***** Welcome to Code Restaurant *****
#
#
# For how many people: 7
# Table number for 7 person : (7, 8)
# Select a Table as per table number: 7
#
# Kindly take your seats Waiter 4 will take your order
#
#  Hello Sir\Mam I'm Waiter 4  Here is our Menu Card
#
# **************************** | MENU | ****************************
#
# _____( Starter )_____
#
#  {1: 'Papad', 2: 'Tamato soup', 3: 'Gobi Tikka', 4: 'Mashroom Tikka', 5: 'Rolls'}
#
# _____( Main Course )_____
#
#  {1: 'Veg Biryani', 2: 'Shahi Paneer', 3: 'Daal Tadka', 4: 'Dudh Sev'}
#
# _____( Desert )_____
#
#  {1: 'Chocolate Ice Cream', 2: 'Butter-scotch Ice Cream', 3: 'Gulab Jamun'}
#
# ************************************************************
# What you like to order: Rolls
# Rs: 75
# What you like to order: Rolls
# Rs: 75
# What you like to order: Papad
# Rs: 35
# What you like to order: Daal Tadka
# Rs: 110
# What you like to order: n
#
#  $$$ Thank you for odering , Your bill is $$$
#
# Rs= 295 + 18% GST
# ...

# %%
starter_menu = list(starter_rs.items())
index=0
while (len(starter_menu[0])) < (len(starter_menu)):
    print('Item',' '*25,'Rate\n','*'*35)
    
    break
# Out:
# Item                           Rate
#  ***********************************
