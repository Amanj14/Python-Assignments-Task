# %% [markdown]
# # PROJECT

# %% [markdown]
# ## Used car in Different Cities

# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import re
import seaborn as sns

# %% [markdown]
# # Data collection

# %%
price = []
company = []
model = []
variant = []
km = []
engine_type = []
location = []
year = []
for i in range(1,100):
    url1 = 'https://www.cartrade.com/buy-used-cars/#so=-1&sc=-1&city='+str(i)
    page = requests.get(url1)
    soup = BeautifulSoup(page.text)
    file = soup.find_all('div', class_="cr_prc")

    for i in file:
        a = i.text
        price.append(a.split()[0])

    file = soup.find_all('div', class_='details_out')

    for i in file:
        a = i.text.split()
        model.append(a[2])
        year.append(*a[0].split())
        company.append(a[1])
        variant.append(a[3])

    file = soup.find_all('div', class_='info_cr_new')

    for i in file:
        a = i.text
        km.append(a.split("|")[0])
        engine_type.append(a.split("|")[1])
        location.append(a.split("|")[2].split()[0])

# %% [markdown]
# # Data-Frame

# %%
data = {"Company":company, "Model":model, "Variant":variant,"Engine Type":engine_type, "Year":year, "Driven":km, "Price":price, "Location":location}

# %%
df = pd.DataFrame(data)
df
# Out:
#          Company    Model    Variant Engine Type  Year      Driven  \
# 0         Nissan  Terrano         XL      Diesel  2015  78,254 KMs
# 1        Hyundai    Elite        i20      Petrol  2015  59,235 KMs
# 2         Maruti   Suzuki      Swift      Diesel  2017  31,000 KMs
# 3         Maruti   Suzuki     Baleno      Petrol  2019  38,807 KMs
# 4         Maruti   Suzuki     Baleno      Petrol  2021  14,213 KMs
# ...          ...      ...        ...         ...   ...         ...
# 3161         Kia    Sonet        GTX      Petrol  2021  22,379 KMs
# 3162      Toyota  Corolla      Altis      Petrol  2017  49,531 KMs
# 3163         Kia    Sonet        GTX      Petrol  2020  14,454 KMs
# 3164       Honda     City         VX      Petrol  2017  72,043 KMs
# 3165  Volkswagen     Polo  Trendline      Petrol  2020  45,169 KMs
#
#            Price  Location
# 0      ₹4,28,000   Gurgaon
# 1      ₹5,21,000    Mumbai
# 2      ₹6,40,000     Delhi
# 3      ₹6,50,000    Ranchi
# 4      ₹7,20,000     Delhi
# ...          ...       ...
# 3161  ₹11,18,000  Zirakpur
# 3162  ₹10,31,000  Zirakpur
# 3163  ₹10,58,000  Zirakpur
# 3164   ₹7,23,000    Mumbai
# 3165   ₹5,43,000  Zirakpur
#
# [3166 rows x 8 columns]

# %%
# df.to_csv("Aman_Project_Page_100.csv")

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## - Type Casting

# %%
df['Year'] = df['Year'].astype('int32')

# %%
df['Price'] = [re.sub(r"[^\d+]","",i)for i in df['Price']]
df['Price'] = df['Price'].astype('int32')

# %%
df['Driven'] = [re.sub(r"[^\d+]","",i) for i in df['Driven']]
df['Driven'] = df['Driven'].astype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3166 entries, 0 to 3165
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      3166 non-null   object
#  1   Model        3166 non-null   object
#  2   Variant      3166 non-null   object
#  3   Engine Type  3166 non-null   object
#  4   Year         3166 non-null   int32
#  5   Driven       3166 non-null   int32
#  6   Price        3166 non-null   int32
#  7   Location     3166 non-null   object
# dtypes: int32(3), object(5)
# memory usage: 160.9+ KB

# %%
# Year wise calculations KDE ==> Done
# Company wise bar plot ==> Done
# Model wise
# Engine type and year wise Voilen ==> done 
# Price wise (scattler)
# Location wise
# Price wise Year
# Company wise pie plot ==> done

# %%
df
# Out:
#          Company    Model    Variant Engine Type  Year  Driven    Price  \
# 0         Nissan  Terrano         XL      Diesel  2015   78254   428000
# 1        Hyundai    Elite        i20      Petrol  2015   59235   521000
# 2         Maruti   Suzuki      Swift      Diesel  2017   31000   640000
# 3         Maruti   Suzuki     Baleno      Petrol  2019   38807   650000
# 4         Maruti   Suzuki     Baleno      Petrol  2021   14213   720000
# ...          ...      ...        ...         ...   ...     ...      ...
# 3161         Kia    Sonet        GTX      Petrol  2021   22379  1118000
# 3162      Toyota  Corolla      Altis      Petrol  2017   49531  1031000
# 3163         Kia    Sonet        GTX      Petrol  2020   14454  1058000
# 3164       Honda     City         VX      Petrol  2017   72043   723000
# 3165  Volkswagen     Polo  Trendline      Petrol  2020   45169   543000
#
#       Location
# 0      Gurgaon
# 1       Mumbai
# 2        Delhi
# 3       Ranchi
# 4        Delhi
# ...        ...
# 3161  Zirakpur
# 3162  Zirakpur
# 3163  Zirakpur
# 3164    Mumbai
# 3165  Zirakpur
#
# [3166 rows x 8 columns]

# %% [markdown]
# # Data Visualization

# %%
df = df.drop_duplicates()

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# - Analysis of the used car market in India:
# - the number of used cars available for sale
# - the average price of used cars

# %%
df
# Out:
#        Company    Model Variant Engine Type  Year  Driven    Price   Location
# 0       Nissan  Terrano      XL      Diesel  2015   78254   428000    Gurgaon
# 1      Hyundai    Elite     i20      Petrol  2015   59235   521000     Mumbai
# 2       Maruti   Suzuki   Swift      Diesel  2017   31000   640000      Delhi
# 3       Maruti   Suzuki  Baleno      Petrol  2019   38807   650000     Ranchi
# 4       Maruti   Suzuki  Baleno      Petrol  2021   14213   720000      Delhi
# ...        ...      ...     ...         ...   ...     ...      ...        ...
# 3107   Hyundai    Elite     i20      Petrol  2016   61672   560000     Nagpur
# 3109        MG   Hector    Plus      Petrol  2022   22040  1850000       Navi
# 3137   Hyundai    Xcent       S      Petrol  2015   39200   499000     Tumkur
# 3138  Mahindra   XUV500      W6      Diesel  2014  114602   850000  Hyderabad
# 3140   Renault   Duster     110      Diesel  2012   87000   325000     Kharar
#
# [457 rows x 8 columns]

# %%
max_pr
sns.lineplot(x = "Location", y = "Price", data = df_less_ten, color='#990033')
plt.title("More than 20 lakh")
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_less_ten = df[df['Price']<1000000].value_counts().reset_index()
sns.lineplot(x = "Location", y = "Price", data = df_less_ten, color='#990033')
plt.title("Less than 10 lakh")
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# - Analysis of the used car market in a specific city
# - the average price of used cars in that city

# %% [markdown]
# - Analysis of the factors that affect the price of used cars:
# - the age of the car and the demand for the car.

# %% [markdown]
# # Que.
# - Which year is having max count of manufacturing

# %% [markdown]
# - Vehicles having max number of year manufacturing count

# %%
# Year wise
sns.histplot(data=df, x="Year",color='#006622', kde=True)
plt.title("Manufacturing Year of Vehicles")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Que.
# - Vehicle having price year wise

# %%
# Prices mean
#df.pivot_table(index = ['Year'], aggfunc ='size')
pr_yr = df.groupby(df['Year'])['Price'].sum().reset_index()
pr_yr
# Out:
#     Year      Price
# 0   2007     290000
# 1   2008     499000
# 2   2010    1916000
# 3   2011    4700000
# 4   2012   17866000
# 5   2013   12055000
# 6   2014   25814710
# 7   2015   55606999
# 8   2016   40148999
# 9   2017   99480800
# 10  2018  111048398
# 11  2019  103032500
# 12  2020   50096598
# 13  2021  114061499
# 14  2022   97014990
# 15  2023    8100000

# %% [markdown]
# # Que.
# - Company wise price

# %%
# price plot
(df.groupby(df['Company'])['Price'].mean().reset_index())
# Out:
#           Company         Price
# 0            Audi  3.560200e+06
# 1             BMW  4.572148e+06
# 2       Chevrolet  1.883333e+05
# 3          Datsun  3.475000e+05
# 4            Ford  1.533033e+06
# 5           Honda  6.291579e+05
# 6         Hyundai  6.642153e+05
# 7          Jaguar  3.515000e+06
# 8            Jeep  2.563750e+06
# 9             Kia  1.658500e+06
# 10           Land  5.484427e+06
# 11             MG  1.643429e+06
# 12           MINI  4.500000e+06
# 13       Mahindra  1.086278e+06
# 14         Maruti  5.285269e+05
# 15  Mercedes-Benz  4.127410e+06
# 16         Nissan  4.280000e+05
# 17        Porsche  7.493000e+06
# 18        Renault  4.890909e+05
# 19          Skoda  1.354688e+06
# 20      Ssangyong  3.900000e+05
# 21           Tata  9.951380e+05
# 22         Toyota  2.106456e+06
# 23     Volkswagen  1.284455e+06
# 24          Volvo  3.425000e+06

# %% [markdown]
# # Que.
# - Company = price < 10 lac
# - Company = price > 20 lac

# %%
low_pr = df[df['Price']<=1000000]
max_pr = df[df['Price']>2000000]

# %%
max_pr
# Out:
#             Company     Model    Variant Engine Type  Year  Driven    Price  \
# 5              Jeep   Compass    Limited      Diesel  2020   17953  2650000
# 6               BMW         5     Series      Diesel  2020   10000  5500000
# 32             Audi        A5  Sportback      Diesel  2018   48000  3700000
# 37    Mercedes-Benz       GLS      Grand      Diesel  2017   60000  5765000
# 96    Mercedes-Benz   C-Class          C      Diesel  2017   63000  2650000
# ...             ...       ...        ...         ...   ...     ...      ...
# 2882           Land     Rover  Discovery      Diesel  2018   35153  3790000
# 2915         Toyota  Fortuner   Legender      Diesel  2021   28000  4650000
# 2945       Mahindra    XUV700         AX      Diesel  2022   21148  2700000
# 2981  Mercedes-Benz       GLE        250      Diesel  2016  100000  3450000
# 3074  Mercedes-Benz       GLE        350      Diesel  2017   89393  4875000
#
#        Location
# 5     Bangalore
# 6        Mumbai
# 32        Delhi
# 37        Delhi
# 96       Mumbai
# ...         ...
# 2882     Karnal
# 2915       Pune
# 2945     Mumbai
# 2981       Pune
# 3074  Bangalore
#
# [108 rows x 8 columns]

# %% [markdown]
# # Que.
# - Engine type max count

# %%
# Engine type and year wise
sns.violinplot(x=df["Engine Type"], y=df["Year"])
plt.show()

# %% [markdown]
# # Que.
# - Company wise no. of count

# %%
dup_company = df.pivot_table(index = ['Company'], aggfunc ='size')
dup_company.reset_index()
# Out:
#           Company    0
# 0            Audi   15
# 1             BMW   21
# 2       Chevrolet    3
# 3          Datsun    2
# 4            Ford   15
# 5           Honda   38
# 6         Hyundai   72
# 7          Jaguar    3
# 8            Jeep    4
# 9             Kia    6
# 10           Land    7
# 11             MG    7
# 12           MINI    1
# 13       Mahindra   18
# 14         Maruti  100
# 15  Mercedes-Benz   39
# 16         Nissan    1
# 17        Porsche    3
# 18        Renault   11
# 19          Skoda   16
# 20      Ssangyong    1
# 21           Tata   21
# 22         Toyota   39
# 23     Volkswagen   11
# 24          Volvo    3

# %%
df['Company'].unique()
# Out:
# array(['Nissan', 'Hyundai', 'Maruti', 'Jeep', 'BMW', 'Tata', 'Honda',
#        'Renault', 'Skoda', 'Mahindra', 'Toyota', 'Kia', 'Volkswagen',
#        'Audi', 'Mercedes-Benz', 'Land', 'Ford', 'Porsche', 'MG', 'Volvo',
#        'Datsun', 'Jaguar', 'Ssangyong', 'Chevrolet', 'MINI'], dtype=object)

# %%
# Company wise pie plot
plt.pie(dup_company, labels=df['Company'].unique(), labeldistance=1.15, wedgeprops = { 'linewidth' : 2.5, 'edgecolor' : '#52527a' });

# %% [markdown]
# # Que.
# - Location wise no. of count

# %%
loc_wise = df.pivot_table(index = ['Location'], aggfunc ='size').reset_index()
loc_wise
# Out:
#         Location    0
# 0           Agra    4
# 1      Ahmedabad   14
# 2         Ambala    1
# 3     Aurangabad    2
# 4      Bangalore   29
# 5   Bulandshahar    1
# 6     Chandigarh    1
# 7        Chennai   13
# 8     Coimbatore    4
# 9       Dehradun    2
# 10         Delhi   51
# 11     Faridabad    4
# 12       Gurgaon    4
# 13         Hubli    1
# 14     Hyderabad   26
# 15        Indore    3
# 16        Jaipur    9
# 17     Jalandhar    2
# 18       Jalgaon    1
# 19    Jamshedpur    3
# 20        Kanpur    9
# 21        Karnal    2
# 22        Kharar    1
# 23         Kochi    2
# 24       Kolkata    9
# 25  Kottarakkara    1
# 26       Lucknow   13
# 27      Ludhiana    6
# 28     Mangalore    3
# 29        Mohali    4
# 30        Mumbai  110
# 31        Mysore    1
# 32        Nagpur    8
# 33        Nashik    9
# 34          Navi    7
# 35         Noida    5
# 36     Panchkula    1
# 37         Patna   10
# 38          Pune   30
# 39        Raipur    1
# 40        Rajkot    3
# 41        Ranchi    7
# 42         Ranga    2
# 43      Rudrapur    1
# 44         Salem    3
# 45         Surat    8
# 46         Thane    5
# 47        Tumkur    2
# 48      Vadodara    5
# 49         Vasco    2
# 50      Zirakpur   12

# %% [markdown]
# # Que.
# - Driven year wise

# %%
(df.pivot_table(index=df['Driven'], aggfunc='size').reset_index())
# Out:
#      Driven  0
# 0      1413  1
# 1      3000  1
# 2      4077  1
# 3      4177  1
# 4      4221  1
# ..      ... ..
# 365  159100  1
# 366  164000  1
# 367  173000  1
# 368  176000  1
# 369  190000  1
#
# [370 rows x 2 columns]

# %%
sns.lineplot(x = "Year", y = "Driven", data = df, color='#990033')
plt.show()

# %%
sns.countplot(x='Company', data=df)
plt.xticks(rotation=90)
plt.title("Company wise Vehicle")
plt.show()

# %%
sns.countplot(x='Year', data=df)
plt.xticks(rotation=90)
plt.title("Company wise Vehicle")
plt.show()

# %%
sns.countplot(x='Engine Type', data=df)
plt.xticks(rotation=90)
plt.title("Engine wise")
plt.show()
